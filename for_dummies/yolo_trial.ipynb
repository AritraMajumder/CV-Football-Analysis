# %% [markdown]
# ### JUST CHECKING OUT YOLO FUNCTIONS

# %%
from ultralytics import YOLO

# %%
model = YOLO('models/best.pt')
#best weights from trained model

# %%
res = model.predict(r'D:\projects\2. Computer Vision\yolo-football\vids\08fd33_4.mp4',save=True)
#predicted video saved under "runs"
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) D:\projects\2. Computer Vision\yolo-football\vids\08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 83.1ms
# video 1/1 (frame 2/750) D:\projects\2. Computer Vision\yolo-football\vids\08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 43.0ms
# ...

# %%
print(res[0]) #indexes are frame numbers
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
# obb: None
# orig_img: array([[[100, 146, 105],
#         [ 92, 138,  97],
#         [ 97, 150, 101],
#         ...,
#         [100,  92,  82],
#         [103,  95,  85],
#         [105,  97,  87]],
#
#        [[ 99, 145, 104],
#         [ 99, 145, 104],
#         [109, 162, 113],
#         ...,
#         [105,  97,  87],
#         [107,  99,  89],
#         [108, 100,  90]],
#
#        [[ 96, 149, 100],
#         [105, 158, 109],
#         [112, 170, 113],
#         ...,
#         [106,  98,  88],
#         [108, 100,  90],
#         [110, 102,  92]],
#
#        ...,
#
#        [[ 74, 103,  78],
#         [ 74, 103,  78],
#         [ 74, 103,  78],
#         ...,
#         [ 30,  47,  43],
#         [ 31,  48,  44],
#         [ 31,  48,  44]],
#
#        [[ 74, 103,  78],
# ...

# %%
#every detected object in SINGLE FRAME gets assigned classification box(pretrained)
for box in res[0].boxes:
    print(box)
    print("__________________")
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9328], device='cuda:0')
# data: tensor([[848.1639, 633.4897, 901.8479, 721.0300,   0.9328,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[875.0059, 677.2599,  53.6840,  87.5403]], device='cuda:0')
# xywhn: tensor([[0.4557, 0.6271, 0.0280, 0.0811]], device='cuda:0')
# xyxy: tensor([[848.1639, 633.4897, 901.8479, 721.0300]], device='cuda:0')
# xyxyn: tensor([[0.4418, 0.5866, 0.4697, 0.6676]], device='cuda:0')
# __________________
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9299], device='cuda:0')
# data: tensor([[1.3093e+03, 4.4788e+02, 1.3510e+03, 5.1651e+02, 9.2992e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# ...
